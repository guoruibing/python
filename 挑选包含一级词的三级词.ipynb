# %%
import numpy as np
import pandas as pd

# %%
thirdword = pd.read_table('C:\\Users\\Administrator\\Desktop\\thirdword.txt',header = None)
thirdword
# Out:
#         0       1       2       3
# 0      投资    术品投资  192754  substr
# 1      投资  化艺术品投资  192286  substr
# 2      管理    企业管理  150852  substr
# 3      邮政    中国邮政   56247  substr
# 4      石油    国石油天   28950  substr
# 5      石油  国石油天然气   28716  substr
# 6      发展  生态农业发展   22788  substr
# 7      农业  农业科技发展   22577  substr
# 8      发展    企业发展   15576  substr
# 9      农业  农业科技开发   15387  substr
# 10     服务    企业服务   13981  substr
# 11     经济    股份经济   11867  substr
# 12     五金    五金交电   10919  substr
# 13     科技  生态农业科技   10542  substr
# 14     商贸    伟业商贸   10418  substr
# 15     银行  中国工商银行   10288  substr
# 16     经纪    手车经纪    9265  substr
# 17     科技    世纪科技    8861  substr
# 18     商贸    世纪商贸    8834  substr
# 19     通信    移动通信    7992  substr
# 20     药房  药房医药连锁    7281  substr
# 21     科技    伟业科技    7007  substr
# 22     房产  房产营销策划    6802  substr
# 23     贸易    发区贸易    6754  substr
# 24     策划    企业策划    6529  substr
# 25     咨询    企业咨询    6377  substr
# ...

# %%
thirdwords = thirdword.iloc[:,1]
thirdwords
# Out:
# 0          术品投资
# 1        化艺术品投资
# 2          企业管理
# 3          中国邮政
# 4          国石油天
# 5        国石油天然气
# 6        生态农业发展
# 7        农业科技发展
# 8          企业发展
# 9        农业科技开发
# 10         企业服务
# 11         股份经济
# 12         五金交电
# 13       生态农业科技
# 14         伟业商贸
# 15       中国工商银行
# 16         手车经纪
# 17         世纪科技
# 18         世纪商贸
# 19         移动通信
# 20       药房医药连锁
# 21         伟业科技
# 22       房产营销策划
# 23         发区贸易
# 24         企业策划
# 25         企业咨询
# 26       文化艺术发展
# 27       建设项目管理
# 28         通达商贸
# 29       文化产业发展
#           ...
# 55911      锦城餐饮
# 55912      蜀山餐饮
# 55913      东城餐饮
# 55914      关东餐饮
# 55915      大利餐饮
# 55916      樊市餐饮
# 55917      山河餐饮
# 55918      南召餐饮
# 55919      长武餐饮
# 55920      米兰餐饮
# 55921      第二餐饮
# 55922      德安餐饮
# 55923      前海餐饮
# 55924      灵璧餐饮
# 55925      李氏餐饮
# 55926    东湖餐饮贸易
# 55927      阿里餐饮
# 55928    市开发区餐饮
# 55929    餐饮营销策划
# 55930      绿源餐饮
# 55931      婺源餐饮
# 55932      礼泉餐饮
# 55933      刚山餐饮
# 55934      天空餐饮
# ...

# %%
f = []
for i in range(thirdwords.index.size):
    if len(thirdwords.iloc[i])>4:
        f.append(i)
print(f)
# Out:
# [1, 5, 6, 7, 9, 13, 15, 20, 22, 26, 27, 29, 30, 39, 43, 49, 53, 54, 55, 59, 66, 68, 69, 70, 73, 75, 76, 77, 80, 82, 91, 93, 97, 106, 111, 116, 119, 120, 124, 125, 130, 136, 137, 141, 145, 152, 153, 154, 156, 157, 158, 159, 161, 163, 164, 169, 174, 183, 186, 188, 190, 196, 198, 200, 202, 204, 206, 209, 212, 214, 224, 230, 231, 233, 236, 242, 249, 252, 255, 258, 268, 271, 272, 279, 281, 289, 291, 293, 301, 302, 304, 306, 307, 309, 315, 320, 330, 331, 332, 336, 339, 342, 346, 352, 363, 364, 369, 370, 371, 372, 373, 382, 383, 384, 394, 396, 398, 403, 408, 411, 418, 422, 426, 430, 431, 432, 433, 439, 440, 443, 445, 448, 449, 452, 457, 461, 466, 471, 472, 476, 479, 480, 481, 483, 484, 489, 490, 492, 496, 499, 503, 504, 505, 507, 508, 512, 513, 516, 521, 525, 528, 531, 532, 534, 535, 536, 539, 540, 543, 553, 558, 568, 572, 574, 581, 582, 585, 587, 592, 604, 613, 615, 620, 623, 625, 626, 627, 628, 629, 634, 635, 638, 640, 641, 652, 657, 658, 667, 668, 669, 673, 675, 680, 684, 687, 688, 690, 
# ...

# %%
thirdwordresult = thirdwords[f]
thirdwordresult
# Out:
# 1        化艺术品投资
# 5        国石油天然气
# 6        生态农业发展
# 7        农业科技发展
# 9        农业科技开发
# 13       生态农业科技
# 15       中国工商银行
# 20       药房医药连锁
# 22       房产营销策划
# 26       文化艺术发展
# 27       建设项目管理
# 29       文化产业发展
# 30       国际文化传媒
# 39       现代农业发展
# 43       农业科技服务
# 49       投资信息咨询
# 53       国际文化传播
# 54       五金塑胶制品
# 55       保税港区投资
# 59       术开发区贸易
# 66       移动通信集团
# 68       房产中介服务
# 69       金属丝网制品
# 70       国际文化发展
# 73       现代农业科技
# 75       电子信息技术
# 76       化工产品销售
# 77       五金机电设备
# 80       生产资料服务
# 82       国际文化交流
#           ...
# 55798    集团吴江纺织
# 55799    集团餐饮娱乐
# 55800    建设集团建材
# 55801    商业集团百货
# 55802    钼业集团矿业
# 55803    集团襄樊销售
# 55820    南陵食品商贸
# 55824    食品机械工业
# 55825    食品投资控股
# 55827    食品原料销售
# 55828    国际农业食品
# 55830    区食品机械厂
# 55832    国营海丰食品
# 55851    合实验区食品
# 55853    食品百货贸易
# 55855    食品原料供应
# 55861    化食品罐头厂
# 55864    园区金龙食品
# 55868    食品机械经销
# 55869    涪陵工矿食品
# 55872    镇宁自治食品
# 55876    食品机械实业
# 55879    食品专销配送
# 55888    潭食品小卖部
# ...

# %%
thirdwordresult.iloc[22437]
# Out:
# '麻辣烫餐饮店'

# %%
firstword = pd.read_table('C:\\Users\\Administrator\\Desktop\\firstword.txt',header = None)
firstword
# Out:
#        0
# 0     商贸
# 1     贸易
# 2     科技
# 3     实业
# 4     建材
# 5     投资
# 6     发展
# 7     工贸
# 8     农业
# 9     装饰
# 10    物流
# 11    食品
# 12    化工
# 13    电子
# 14    服饰
# 15    建筑
# 16    种植
# 17    物资
# 18    五金
# 19    咨询
# 20    信息
# 21    经纪
# 22    养殖
# 23    经贸
# 24    药房
# 25    电器
# 26    服装
# 27    管理
# 28    汽车
# 29    机械
# ...   ..
# 4287  开挖
# 4288  投标
# 4289  幼儿
# 4290  报刊
# 4291  手架
# 4292  草药
# 4293  准件
# 4294  鉴定
# 4295  车场
# 4296  入境
# 4297  液化
# 4298  驾驶
# 4299  固件
# 4300  构件
# 4301  批发
# 4302  织品
# 4303  收购
# 4304  动车
# 4305  药材
# 4306  产权
# 4307  材料
# 4308  石方
# 4309  作物
# 4310  配件
# 4311  工程
# 4312  产品
# 4313  设备
# 4314  制品
# 4315  加工
# 4316  艺术
#
# [4317 rows x 1 columns]

# %%
firstword.iloc[4316]
# Out:
# 0    艺术
# Name: 4316, dtype: object

# %%
thirdwordresult.index.size
# Out:
# 22438

# %%
thirdwordresult.iloc[22434][4:6] in str(firstword)
# Out:
# True

# %%
w1 = []
w2 = []
for j in range(thirdwordresult.index.size):
    str1 = thirdwordresult.iloc[j][0:2]
    str2 = thirdwordresult.iloc[j][2:4]
    str3 = thirdwordresult.iloc[j][4:6]
    if str1 in str(firstword) and str2 in str(firstword) and str3 in str(firstword):
        w1.append(j)
    else:
        w2.append(j)
print(w1)
print(w2)
# Out:
# [3, 15, 33, 63, 112, 172, 194, 201, 223, 226, 236, 243, 256, 410, 434, 449, 480, 503, 504, 511, 526, 535, 537, 565, 567, 589, 631, 632, 646, 710, 719, 761, 764, 768, 771, 817, 837, 851, 857, 913, 946, 963, 971, 1021, 1028, 1030, 1056, 1063, 1102, 1106, 1200, 1206, 1221, 1229, 1236, 1239, 1243, 1247, 1265, 1312, 1315, 1355, 1375, 1406, 1469, 1496, 1504, 1532, 1611, 1655, 1675, 1732, 1760, 1764, 1771, 1772, 1798, 1826, 1884, 1906, 1920, 2037, 2060, 2111, 2114, 2118, 2128, 2151, 2166, 2167, 2187, 2230, 2268, 2274, 2275, 2307, 2312, 2327, 2404, 2427, 2441, 2472, 2474, 2479, 2496, 2497, 2576, 2688, 2693, 2746, 2757, 2867, 2877, 2879, 2880, 2914, 2918, 2944, 3006, 3018, 3170, 3227, 3258, 3297, 3300, 3435, 3438, 3502, 3528, 3531, 3544, 3688, 3710, 3813, 3827, 3829, 3904, 4024, 4144, 4165, 4169, 4243, 4262, 4264, 4267, 4284, 4366, 4395, 4396, 4403, 4407, 4410, 4443, 4497, 4514, 4521, 4553, 4585, 4591, 4617, 4626, 4796, 4816, 4835, 4842, 4869, 4872, 4875, 4885, 4910, 4913, 4923, 4958, 4987, 4
# ...

# %%
thirdwordresult.iloc[w1].to_csv('C:\\Users\\Administrator\\Desktop\\end1.csv', encoding = 'utf-8', index = False)
thirdwordresult.iloc[w2].to_csv('C:\\Users\\Administrator\\Desktop\\end2.csv', encoding = 'utf-8', index = False)
